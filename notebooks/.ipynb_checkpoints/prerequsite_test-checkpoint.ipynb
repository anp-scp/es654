# %%
import random
import time
import numpy
import copy
import jax
import sympy
from IPython.display import display, Markdown
# sympy.init_printing(use_unicode=True)
import pprint
import matplotlib.pyplot as plt
import panda
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [149], in <cell line: 11>()
#       9 import pprint
#      10 import matplotlib.pyplot as plt
# ---> 11 import panda
#
# ModuleNotFoundError: No module named 'panda'

# %% [markdown]
# ### ***Question 1:*** How many multiplications and additions do you need to perform a matrix multiplication between a (n, k) and (k, m) matrix? Explain.
#
# ***Answer:*** Let, $A_{n,k}$ and $B_{k,m}$ be two matries. $A \times B = C_{n,m}$.
# Each element $c_{i,j}$ in ***C***, is a dot product of $i^{th}$ row of matrix ***A*** and $j^{th}$ column of matrix ***B***. And this dot product would need ***k*** multiplications and ***k-1*** additions.
# To compute each element of ***C*** we need ***k*** multiplications and ***k-1*** additions. Since, ***C*** will have $n*m$ elements, total number of multiplications would be $n \times m \times k$ and total additions would be $n \times m \times (k-1)$.

# %% [markdown]
# ### ***Question 2:*** Write Python code to multiply the above two matrices. Solve using list of lists and then use numpy. Compare the timing of both solutions. Which one is faster? Why?
#
# ***Answer:*** In below code cell.

# %%
n=512
k=550
m=535
A = [[random.randint(0,100) for i in range(0,k)] for j in range(0,n)] #nxk matrix
B = [[random.randint(0,100) for i in range(0,m)] for j in range(0,k)] #kxm matrix
C = [[0 for i in range(0,m)] for j in range(0,n)] #nxm matrix

naiveStart = time.process_time_ns()
for i in range(0,n):
    for j in range(0,m):
        sum = 0
        for K in range(0,k):
            sum += A[i][K] * B[K][j]
        C[i][j] = sum
naiveEnd = time.process_time_ns()
numpyStart = time.process_time_ns()
C_numpy = numpy.matmul(A,B)
numpyEnd = time.process_time_ns()
compare = C_numpy == numpy.array(C)
assert compare.all() == True
print("Total time for naive multiplication:  {0:.9f}s".format((naiveEnd-naiveStart)/1000000000))
print("Multiplication time for numpy multiplication:    {0:.9f}s".format((numpyEnd-numpyStart)/1000000000))
# Out:
# Total time for naive multiplication:  57.623331324s
# Multiplication time for numpy multiplication:    0.441162272s

# %% [markdown]
# ***Numpy*** is faster because of the following reasons:
#
# * In the naive approach considerable amount of time is spent on data movement from memory to cache and vice versa. Numpy uses optimised Basic Linear Algebra Subprograms (BLAS) for efficient data movement between cache and memory. There are multiple such algorithms and one such algorithm performs the matrix multiplication by partitioning one matrices into smaller blocks/submatrices and then multiplying smilar to multiplying with scalar elements but the scalar elements replced with sub matrices.
# * The naive apprach is a single threaded approach whereas numpy uses multi threading to make the process faster.
# * In numpy array, the elements are homogenous. But, in python list elements can be of different types. And this needs lot checks and conversions.
#
# Sources:
# * https://numpy.org/doc/stable/reference/generated/numpy.matmul.html#numpy.matmul
# * https://www.cs.utexas.edu/users/rvdg/tmp/TSoPMC.pdf

# %% [markdown]
# ### ***Question 3:*** Finding the highest element in a list requires one pass of the array. Finding the second highest element requires 2 passes of the the array. Using this method, what is the time complexity of finding the median of the array? Can you suggest a better method? Can you implement both these methods in Python and compare against numpy.median routine in terms of time?
#
# ***Answer:*** Finding the median using the naive way described in the question would need $\frac{n}{2} + 1$ passes in the worst case. The time complexity for this would be: $T(n) = n + (n-1) + (n-2) + \ldots \frac{n}{2} = O(n^2)$.
#
# A better method would be as ahown in below psuedocode:
#
# ```
# FindMedian(list[1...n], pos):
#     if n==1:
#         return list[1]
#     else:
#         for i=1 to floor(n/5): ### time taken here is O(n)
#             M[i] = naiveMedian(list[5i-4...5i])
#         medianOfMediansIndex = FindMedian(M,floor(n/10)) ### time taken here is T(n/5)
#         index = quickSortPartition(list[1...n], medianOfMediansIndex) ### time taken here is O(n)
#         if index == pos:
#             return list[pos]
#         else if index > pos:
#             FindMedian(list[1..index-1],k) ### time taken here is T(7n/10)
#         else:
#             FindMedian(list[index+1],k-index) ### time taken here is T(7n/10)
# ```
# In case of odd sized list we can simply call `FindMedian(list, ceil(n/2))`. Otherwise, we can call the function once for position $\frac{n}{2}$ and once for $\frac{n}{2}+1$ and return the average.
#
# We call the above method as ***Median of Median method***
#
# In the above algorithm, the pivot for partitioning would be a number in the position between $\frac{3n}{10}$ and $\frac{7n}{10}$ psoitions. So, the time complexity can be represented as $T(n) \leq T(\frac{n}{5}) + T(\frac{7n}{10}) + cn$
#
# This recurrence relation can be solved as follows:
# * Let us guess that $T(n) \leq c'n$ and $T(1) = c$ where $c' > c$
# * Base Case: when $n = 1$, $T(1) = c \implies T(1) \leq c'$
# * Induction Hypothesis: Let us assume that $T(n) \leq c'n $ holds for all $T(1), T(2), \ldots, T(n-1)$
# * Inductive step is as follows:
#
# \begin{aligned}
#     T(n) &\leq T(\frac{n}{5}) + T(\frac{7n}{10}) + cn\\
#     &\leq \frac{c'n}{5} + \frac{c'7n}{10} + cn\\
#     &\leq n*(\frac{9c'}{10} + c)
# \end{aligned}
# * As per guess:
# \begin{aligned}
#     c' &= \frac{9c'}{10} + c\\
#     &= 10c\\
#     \implies c' &> c
# \end{aligned}
# * Therefore, our guess is correct and $T(n) \leq c'n = O(n)$

# %%
#implementation of above suggested code : the median of median method
def partition(array, low, high, momi):
    (array[momi], array[high]) = (array[high], array[momi])
    pivot = array[high]
    i = low - 1
    for j in range(low, high):
        if array[j] <= pivot:
            i = i + 1
            (array[i], array[j]) = (array[j], array[i])
    (array[i + 1], array[high]) = (array[high], array[i + 1])
    return i + 1

def findkth(ip, pos):
    ip = copy.deepcopy(ip)
    if len(ip) < 5:
        ip = sorted(ip)
        return ip[pos]
    else:
        n = len(ip)
        medians = list()
        for i in range(1,(n//5)+1):
            temp = ip[(5*i)-5:5*i]
            temp = sorted(temp)
            medians.append(temp[2])
        mom = findkth(medians, (n//10))
        momi = ip.index(mom)
        index = partition(ip,0,n-1,momi)
        if index == pos:
            return ip[pos]
        elif index > pos:
            return findkth(ip[0:index], pos)
        else:
            return findkth(ip[index+1:], pos-index-1)
def findMedianMOM(ip):
    n = len(ip)
    assert n>0, "empty input list"
    if n%2 != 0:
        return findkth(ip, n//2)
    else:
        ip1 = copy.deepcopy(ip)
        m1 = findkth(ip, (n//2)-1)
        m2 = findkth(ip, (n//2))
        return (m1+m2)/2

# %%
# implementation of the multiple pass method
def findMax(ip):
    maxm = ip[0]
    for i in range(1,len(ip)):
        if maxm < ip[i]:
            maxm = ip[i]
    return maxm

def findMedianMultiPass(ip):
    n = len(ip)
    assert n>0, "invalid input list"
    halfn = n//2
    k = n-1
    m1 = 0
    while k>= halfn:
        m1 = findMax(ip)
        ip.remove(m1)
        k = k -1
    if n%2!=0:
        return m1
    else:
        m2 = findMax(ip)
        return (m1+m2)/2

# %%
# nums = [random.randint(0,4096) for i in range(0,1048576)]
nums = [random.randint(0,4096) for i in range(0,14096)]
nums_numpy = copy.deepcopy(nums)
nums_multiPass = copy.deepcopy(nums)

# %%
# %%time
medianMultiPass = findMedianMultiPass(nums_multiPass)
# Out:
# CPU times: user 7.16 s, sys: 3.99 ms, total: 7.17 s
# Wall time: 7.17 s

# %%
# %%time
medianMOM = findMedianMOM(nums)
# Out:
# CPU times: user 120 ms, sys: 0 ns, total: 120 ms
# Wall time: 122 ms

# %%
# %%time
numpyMedian = numpy.median(nums_numpy)
# Out:
# CPU times: user 4.43 ms, sys: 0 ns, total: 4.43 ms
# Wall time: 3.51 ms

# %%
# testing purpose
# for i in range(50):
#     size = random.randint(100,1048576)
#     nums = [random.randint(0,4096) for i in range(0,size)]
#     nums_numpy = copy.deepcopy(nums)
#     mom = findMedian(nums)
#     numpyMedian = numpy.median(nums_numpy)
#     print(mom == numpyMedian)
print("Median by multi pass: {0}".format(medianMultiPass))
print("Median by median of median method: {0}".format(medianMOM))
print("Median by numpy: {0}".format(numpy.median(nums)))
assert medianMultiPass == medianMOM and medianMOM == numpyMedian
# Out:
# Median by multi pass: 2042.0
# Median by median of median method: 2042.0
# Median by numpy: 2042.0

# %% [markdown]
# ### ***Question 4:*** What is the gradient of the following function with respect to x and y?
# $$
#     x^2y + y^3sin(x)
# $$
# ***Answer:*** The gradient is :
# $$
# \begin{bmatrix}
#     2xy + y^3cos(x) \\ x^2 + 3y^2sin(x)
# \end{bmatrix}
# $$

# %% [markdown]
# ### ***Question 5:*** Use JAX to confirm the gradient evaluated by your method matches the analytical solution corresponding to a few random values of x and y
#
# ***Answer:*** See cells below:

# %%
## the given function
def function(x,y):
    return (x**2) * y + (y**3) * jax.numpy.sin(x)
## explicit function to calculate gradient
def function_grad(x,y):
    result = [2*x*y+(y**3)*jax.numpy.cos(x), x**2 + 3*(y**2)*jax.numpy.sin(x)]
    return jax.numpy.array(result)
## function to calculate gradient using jax
jax_grad = jax.grad(function,(0,1))
print("function(pi/2,2.0):{0}".format(function(jax.numpy.pi/2,2.0)))
print("gradient using explicit gradient function: {0}".format(function_grad(jax.numpy.pi/2,2.0)))
print("gradient using jax gradient function: {0}".format(jax_grad(jax.numpy.pi/2,2.0)))
# Out:
# function(pi/2,2.0):12.934802055358887
# gradient using explicit gradient function: [ 6.283185  14.4674015]
# gradient using jax gradient function: (Array(6.283185, dtype=float32, weak_type=True), Array(14.4674015, dtype=float32, weak_type=True))

# %% [markdown]
# ### ***Question 6:*** Use sympy to confirm that you obtain the same gradient analytically.
# ***Answer:*** See cells below

# %%
def printMessageExpr(message, expr):
    display(Markdown(message.format(sympy.latex(expr, mode='inline'))))
x,y = sympy.symbols('x y')
sympy_func = (x**2) * y + (y**3) * sympy.sin(x)
printMessageExpr("The function is: {0}", sympy_func)
sympy_grad = sympy.Matrix([sympy.diff(sympy_func,x), sympy.diff(sympy_func,y)])
printMessageExpr("The gradient is: {0}", sympy_grad)
sympy_grad_eval = sympy_grad.evalf(subs={x:sympy.pi/2,y:2.0})
printMessageExpr("The gradient on x=pi/2 and y=2.0 is: {0}", sympy_grad_eval)
# Out:
# The function is: $x^{2} y + y^{3} \sin{\left(x \right)}$
# The gradient is: $\left[\begin{smallmatrix}2 x y + y^{3} \cos{\left(x \right)}\\x^{2} + 3 y^{2} \sin{\left(x \right)}\end{smallmatrix}\right]$
# The gradient on x=pi/2 and y=2.0 is: $\left[\begin{smallmatrix}6.28318530717959\\14.4674011002723\end{smallmatrix}\right]$

# %% [markdown]
# ### ***Question 7:*** Create a Python nested dictionary to represent hierarchical information. We want to store record of students and their marks. Something like:
#
# 1. 2022
#     1. Branch 1
#         1. Roll Number: 1, Name: N, Marks:
#             1. Maths: 100, English: 70 …
#     2. Branch 2
# 2. 2023
#     1. Branch 1
#     2. Branch 2
# 3. 2024
#     1. Branch 1
#     2. Branch 2
# 4. 2025
#     1. Branch 1
#     2. Branch 2
#
# ***Answer:*** See code below:

# %%
ourDict = dict()
fnames = ['Alice', 'John', 'Eve', 'Katty', 'Alia', 'Surendra', 'Rajesh', 'Mahesh']
lnames = ['Gupta', 'Sharma', 'Bhardwaj', 'Patel', 'Lodwal', 'Salvi', 'Shah']
years = [2022,2023,2024,2025]
branches = ['CSE', 'ME', 'CG']
subs = ['Maths', 'English', 'ML', 'DL']
for year in years:
    branchDict = dict()
    for branch in branches:
        studentRecords = list()
        for i in range(1,random.randint(4,8)):
            record = dict()
            record['Roll Number'] = i
            record['Name'] = random.choice(fnames) + " " + random.choice(lnames)
            marksDict = dict()
            for sub in subs:
                marksDict[sub] = random.randint(0,100)
            record['Marks'] = marksDict
            studentRecords.append(record)
        branchDict[branch] = studentRecords
    ourDict[year] = branchDict
pprint.pprint(ourDict, sort_dicts=False)
# Out:
# {2022: {'CSE': [{'Roll Number': 1,
#                  'Name': 'Surendra Bhardwaj',
#                  'Marks': {'Maths': 16, 'English': 60, 'ML': 46, 'DL': 78}},
#                 {'Roll Number': 2,
#                  'Name': 'Katty Sharma',
#                  'Marks': {'Maths': 3, 'English': 85, 'ML': 37, 'DL': 17}},
#                 {'Roll Number': 3,
#                  'Name': 'Alia Patel',
#                  'Marks': {'Maths': 17, 'English': 30, 'ML': 18, 'DL': 58}},
#                 {'Roll Number': 4,
#                  'Name': 'Eve Sharma',
#                  'Marks': {'Maths': 26, 'English': 66, 'ML': 2, 'DL': 38}}],
#         'ME': [{'Roll Number': 1,
#                 'Name': 'Katty Patel',
#                 'Marks': {'Maths': 32, 'English': 88, 'ML': 97, 'DL': 71}},
#                {'Roll Number': 2,
#                 'Name': 'Eve Lodwal',
#                 'Marks': {'Maths': 8, 'English': 99, 'ML': 74, 'DL': 43}},
#                {'Roll Number': 3,
#                 'Name': 'Rajesh Lodwal',
#                 'Marks': {'Maths': 71, 'English': 67, 'ML': 33, 'DL': 14}},
#                {'Roll Number': 4,
#                 'Name': 'Eve Sharma',
#                 'Marks': {'Maths': 94, 'English': 53, 'ML': 99, 'DL': 14}},
#                {'Roll Number': 5,
#                 'Name': 'Alice Bhardwaj',
#                 'Marks': {'Maths': 58, 'English': 93, 'ML': 65, 'DL': 57}},
#                {'Roll Number': 6,
#                 'Name': 'Katty Patel',
#                 'Marks': {'Maths': 79, 'English': 6, 'ML': 81, 'DL': 20}},
#                {'Roll Number': 7,
#                 'Name': 'Alice Shah',
#                 'Marks': {'Maths': 100, 'English': 17, 'ML': 1, 'DL': 25}}],
#         'CG': [{'Roll Number': 1,
#                 'Name': 'John Patel',
#                 'Marks': {'Maths': 69, 'English': 90, 'ML': 48, 'DL': 11}},
#                {'Roll Number': 2,
#                 'Name': 'Katty Patel',
#                 'Marks': {'Maths': 24, 'English': 13, 'ML': 11, 'DL': 87}},
#                {'Roll Number': 3,
#                 'Name': 'Alia Patel',
#                 'Marks': {'Maths': 48, 'English': 89, 'ML': 96, 'DL': 57}}]},
#  2023: {'CSE': [{'Roll Number': 1,
#                  'Name': 'John Bhardwaj',
#                  'Marks': {'Maths': 80, 'English': 32, 'ML': 5, 'DL': 37}},
#                 {'Roll Number': 2,
#                  'Name': 'Eve Bhardwaj',
#                  'Marks': {'Maths': 8, 'English': 26, 'ML': 13, 'DL': 74}},
#                 {'Roll Number': 3,
#                  'Name': 'Katty Shah',
#                  'Marks': {'Maths': 31, 'English': 42, 'ML': 26, 'DL': 10}},
#                 {'Roll Number': 4,
#                  'Name': 'Katty Bhardwaj',
#                  'Marks': {'Maths': 99, 'English': 26, 'ML': 91, 'DL': 76}},
#                 {'Roll Number': 5,
#                  'Name': 'Surendra Patel',
#                  'Marks': {'Maths': 77, 'English': 15, 'ML': 32, 'DL': 43}},
#                 {'Roll Number': 6,
#                  'Name': 'Alia Bhardwaj',
#                  'Marks': {'Maths': 2, 'English': 82, 'ML': 12, 'DL': 24}},
#                 {'Roll Number': 7,
#                  'Name': 'Rajesh Lodwal',
#                  'Marks': {'Maths': 67, 'English': 78, 'ML': 20, 'DL': 36}}],
#         'ME': [{'Roll Number': 1,
#                 'Name': 'Alice Patel',
#                 'Marks': {'Maths': 43, 'English': 25, 'ML': 79, 'DL': 15}},
#                {'Roll Number': 2,
#                 'Name': 'Alice Salvi',
#                 'Marks': {'Maths': 35, 'English': 75, 'ML': 17, 'DL': 2}},
#                {'Roll Number': 3,
#                 'Name': 'Katty Gupta',
#                 'Marks': {'Maths': 74, 'English': 78, 'ML': 20, 'DL': 40}},
#                {'Roll Number': 4,
#                 'Name': 'John Bhardwaj',
#                 'Marks': {'Maths': 10, 'English': 55, 'ML': 83, 'DL': 16}},
#                {'Roll Number': 5,
#                 'Name': 'Alice Bhardwaj',
#                 'Marks': {'Maths': 65, 'English': 14, 'ML': 57, 'DL': 44}},
#                {'Roll Number': 6,
#                 'Name': 'Surendra Sharma',
#                 'Marks': {'Maths': 63, 'English': 14, 'ML': 73, 'DL': 48}},
#                {'Roll Number': 7,
#                 'Name': 'John Shah',
#                 'Marks': {'Maths': 87, 'English': 51, 'ML': 32, 'DL': 88}}],
#         'CG': [{'Roll Number': 1,
#                 'Name': 'John Gupta',
#                 'Marks': {'Maths': 60, 'English': 21, 'ML': 64, 'DL': 79}},
#                {'Roll Number': 2,
#                 'Name': 'John Bhardwaj',
#                 'Marks': {'Maths': 27, 'English': 98, 'ML': 49, 'DL': 55}},
#                {'Roll Number': 3,
#                 'Name': 'Rajesh Patel',
#                 'Marks': {'Maths': 92, 'English': 53, 'ML': 83, 'DL': 14}},
#                {'Roll Number': 4,
#                 'Name': 'Rajesh Lodwal',
#                 'Marks': {'Maths': 41, 'English': 22, 'ML': 91, 'DL': 83}},
#                {'Roll Number': 5,
#                 'Name': 'Mahesh Gupta',
#                 'Marks': {'Maths': 82, 'English': 26, 'ML': 44, 'DL': 67}},
#                {'Roll Number': 6,
#                 'Name': 'Katty Bhardwaj',
#                 'Marks': {'Maths': 3, 'English': 52, 'ML': 23, 'DL': 26}}]},
#  2024: {'CSE': [{'Roll Number': 1,
#                  'Name': 'Surendra Bhardwaj',
#                  'Marks': {'Maths': 35, 'English': 26, 'ML': 38, 'DL': 59}},
#                 {'Roll Number': 2,
#                  'Name': 'Eve Lodwal',
#                  'Marks': {'Maths': 36, 'English': 30, 'ML': 82, 'DL': 54}},
#                 {'Roll Number': 3,
#                  'Name': 'Alice Gupta',
#                  'Marks': {'Maths': 27, 'English': 9, 'ML': 42, 'DL': 10}},
#                 {'Roll Number': 4,
#                  'Name': 'Mahesh Lodwal',
#                  'Marks': {'Maths': 28, 'English': 80, 'ML': 38, 'DL': 39}},
#                 {'Roll Number': 5,
#                  'Name': 'Surendra Patel',
#                  'Marks': {'Maths': 22, 'English': 22, 'ML': 32, 'DL': 77}},
#                 {'Roll Number': 6,
#                  'Name': 'Alice Bhardwaj',
#                  'Marks': {'Maths': 29, 'English': 19, 'ML': 20, 'DL': 24}},
#                 {'Roll Number': 7,
#                  'Name': 'Surendra Patel',
#                  'Marks': {'Maths': 0, 'English': 67, 'ML': 43, 'DL': 60}}],
#         'ME': [{'Roll Number': 1,
#                 'Name': 'Mahesh Gupta',
#                 'Marks': {'Maths': 21, 'English': 51, 'ML': 87, 'DL': 46}},
#                {'Roll Number': 2,
#                 'Name': 'Alice Bhardwaj',
#                 'Marks': {'Maths': 9, 'English': 26, 'ML': 93, 'DL': 79}},
#                {'Roll Number': 3,
#                 'Name': 'Alia Sharma',
#                 'Marks': {'Maths': 0, 'English': 2, 'ML': 32, 'DL': 4}},
#                {'Roll Number': 4,
#                 'Name': 'Katty Salvi',
#                 'Marks': {'Maths': 53, 'English': 20, 'ML': 91, 'DL': 99}}],
#         'CG': [{'Roll Number': 1,
#                 'Name': 'John Gupta',
#                 'Marks': {'Maths': 0, 'English': 25, 'ML': 90, 'DL': 8}},
#                {'Roll Number': 2,
#                 'Name': 'Surendra Shah',
#                 'Marks': {'Maths': 66, 'English': 61, 'ML': 80, 'DL': 96}},
#                {'Roll Number': 3,
#                 'Name': 'Alice Bhardwaj',
#                 'Marks': {'Maths': 96, 'English': 11, 'ML': 79, 'DL': 90}},
#                {'Roll Number': 4,
#                 'Name': 'Surendra Sharma',
#                 'Marks': {'Maths': 94, 'English': 8, 'ML': 45, 'DL': 78}},
#                {'Roll Number': 5,
#                 'Name': 'Eve Sharma',
#                 'Marks': {'Maths': 0, 'English': 97, 'ML': 23, 'DL': 1}}]},
#  2025: {'CSE': [{'Roll Number': 1,
#                  'Name': 'Katty Sharma',
#                  'Marks': {'Maths': 82, 'English': 29, 'ML': 84, 'DL': 62}},
#                 {'Roll Number': 2,
#                  'Name': 'Katty Lodwal',
#                  'Marks': {'Maths': 65, 'English': 15, 'ML': 63, 'DL': 92}},
#                 {'Roll Number': 3,
#                  'Name': 'Mahesh Salvi',
#                  'Marks': {'Maths': 89, 'English': 67, 'ML': 84, 'DL': 1}},
#                 {'Roll Number': 4,
#                  'Name': 'John Bhardwaj',
#                  'Marks': {'Maths': 8, 'English': 95, 'ML': 88, 'DL': 7}}],
#         'ME': [{'Roll Number': 1,
#                 'Name': 'John Patel',
#                 'Marks': {'Maths': 86, 'English': 62, 'ML': 85, 'DL': 7}},
#                {'Roll Number': 2,
#                 'Name': 'Katty Patel',
#                 'Marks': {'Maths': 82, 'English': 65, 'ML': 46, 'DL': 5}},
#                {'Roll Number': 3,
#                 'Name': 'Surendra Bhardwaj',
#                 'Marks': {'Maths': 34, 'English': 21, 'ML': 82, 'DL': 19}},
#                {'Roll Number': 4,
#                 'Name': 'Mahesh Salvi',
#                 'Marks': {'Maths': 81, 'English': 80, 'ML': 30, 'DL': 29}},
#                {'Roll Number': 5,
#                 'Name': 'Rajesh Shah',
#                 'Marks': {'Maths': 5, 'English': 7, 'ML': 37, 'DL': 37}}],
#         'CG': [{'Roll Number': 1,
#                 'Name': 'Alia Bhardwaj',
#                 'Marks': {'Maths': 10, 'English': 53, 'ML': 35, 'DL': 29}},
#                {'Roll Number': 2,
#                 'Name': 'Surendra Shah',
#                 'Marks': {'Maths': 91, 'English': 87, 'ML': 56, 'DL': 85}},
#                {'Roll Number': 3,
#                 'Name': 'Alia Salvi',
#                 'Marks': {'Maths': 35, 'English': 37, 'ML': 46, 'DL': 81}}]}}

# %% [markdown]
# ### ***Question 8:*** Store the same information using Python classes. We have an overall database which is a list of year objects. Each year contains a list of branches. Each branch contains a list of students. Each student has some properties like name, roll number and has marks in some subjects.
# ***Answer:*** See below cells:

# %%
class Marks:
    def __init__(self, subject, score):
        self.__subject = subject
        self.__score = score
    def __repr__(self):
        return "[Subject:{0}".format(self.__subject) + " ; " + "Score:{0}]\n".format(self.__score)
class Student:
    def __init__(self, roll, name, marks=None):
        self.__roll = roll
        self.__name = name
        self.__marks = marks if marks is not None else list()
    def addMarks(self, marks):
        self.__marks.append(marks)
    def __repr__(self):
        return "[Roll No.:{0}".format(self.__roll) + " ; " + "Name:{0}".format(self.__name) + " ; " + "Marks:{0}]\n".format(self.__marks)
class Branch:
    def __init__(self,name,students = None):
        self.__name = name
        self.__students = students if students is not None else list()
    def addStudent(self,student):
        self.__students.append(student)
    def __repr__(self):
        return "[Branch:{0}".format(self.__name) + " ; " + "Students:{0}]\n".format(self.__students)
class Year:
    def __init__(self, year, branches=None):
        self.__year = year
        self.__branches = branches if branches is not None else list()
    def addBranch(self,branch):
        self.__branches.append(branch)
    def __repr__(self):
        return "[Year:{0}".format(self.__year) + " ; " + "Branches:{0}]\n".format(self.__branches)
database = list()
for year in years:
    yearObj = Year(year)
    for branch in branches:
        branchObject = Branch(branch)
        for i in range(1,random.randint(2,5)):
            studentObj = Student(i, random.choice(fnames) + " " + random.choice(lnames))
            for sub in subs:
                marksObj = Marks(sub, random.randint(0,100))
                studentObj.addMarks(marksObj)
            branchObject.addStudent(studentObj)
        yearObj.addBranch(branchObject)
    database.append(yearObj)
print(database)
# Out:
# [[Year:2022 ; Branches:[[Branch:CSE ; Students:[[Roll No.:1 ; Name:Eve Bhardwaj ; Marks:[[Subject:Maths ; Score:26]
# , [Subject:English ; Score:9]
# , [Subject:ML ; Score:43]
# , [Subject:DL ; Score:41]
# ]]
# , [Roll No.:2 ; Name:Mahesh Bhardwaj ; Marks:[[Subject:Maths ; Score:17]
# , [Subject:English ; Score:0]
# , [Subject:ML ; Score:53]
# , [Subject:DL ; Score:1]
# ]]
# ]]
# , [Branch:ME ; Students:[[Roll No.:1 ; Name:Eve Bhardwaj ; Marks:[[Subject:Maths ; Score:83]
# , [Subject:English ; Score:100]
# , [Subject:ML ; Score:0]
# , [Subject:DL ; Score:31]
# ]]
# , [Roll No.:2 ; Name:Katty Gupta ; Marks:[[Subject:Maths ; Score:5]
# , [Subject:English ; Score:40]
# , [Subject:ML ; Score:44]
# , [Subject:DL ; Score:85]
# ]]
# , [Roll No.:3 ; Name:Surendra Sharma ; Marks:[[Subject:Maths ; Score:53]
# , [Subject:English ; Score:45]
# , [Subject:ML ; Score:15]
# , [Subject:DL ; Score:36]
# ]]
# , [Roll No.:4 ; Name:Katty Sharma ; Marks:[[Subject:Maths ; Score:57]
# , [Subject:English ; Score:10]
# , [Subject:ML ; Score:40]
# , [Subject:DL ; Score:80]
# ]]
# ]]
# , [Branch:CG ; Students:[[Roll No.:1 ; Name:Rajesh Bhardwaj ; Marks:[[Subject:Maths ; Score:59]
# , [Subject:English ; Score:92]
# , [Subject:ML ; Score:69]
# , [Subject:DL ; Score:23]
# ]]
# , [Roll No.:2 ; Name:Alice Sharma ; Marks:[[Subject:Maths ; Score:92]
# , [Subject:English ; Score:32]
# , [Subject:ML ; Score:83]
# , [Subject:DL ; Score:0]
# ]]
# , [Roll No.:3 ; Name:Rajesh Lodwal ; Marks:[[Subject:Maths ; Score:48]
# , [Subject:English ; Score:3]
# , [Subject:ML ; Score:48]
# , [Subject:DL ; Score:61]
# ]]
# , [Roll No.:4 ; Name:Alice Shah ; Marks:[[Subject:Maths ; Score:12]
# , [Subject:English ; Score:7]
# , [Subject:ML ; Score:64]
# , [Subject:DL ; Score:33]
# ]]
# ]]
# ]]
# , [Year:2023 ; Branches:[[Branch:CSE ; Students:[[Roll No.:1 ; Name:Mahesh Gupta ; Marks:[[Subject:Maths ; Score:26]
# , [Subject:English ; Score:16]
# , [Subject:ML ; Score:65]
# , [Subject:DL ; Score:3]
# ]]
# , [Roll No.:2 ; Name:Mahesh Lodwal ; Marks:[[Subject:Maths ; Score:87]
# , [Subject:English ; Score:43]
# , [Subject:ML ; Score:8]
# , [Subject:DL ; Score:42]
# ]]
# , [Roll No.:3 ; Name:Eve Gupta ; Marks:[[Subject:Maths ; Score:31]
# , [Subject:English ; Score:97]
# , [Subject:ML ; Score:40]
# , [Subject:DL ; Score:93]
# ]]
# ]]
# , [Branch:ME ; Students:[[Roll No.:1 ; Name:Katty Bhardwaj ; Marks:[[Subject:Maths ; Score:61]
# , [Subject:English ; Score:48]
# , [Subject:ML ; Score:88]
# , [Subject:DL ; Score:93]
# ]]
# ]]
# , [Branch:CG ; Students:[[Roll No.:1 ; Name:Katty Lodwal ; Marks:[[Subject:Maths ; Score:63]
# , [Subject:English ; Score:4]
# , [Subject:ML ; Score:68]
# , [Subject:DL ; Score:10]
# ]]
# , [Roll No.:2 ; Name:Surendra Patel ; Marks:[[Subject:Maths ; Score:19]
# , [Subject:English ; Score:63]
# , [Subject:ML ; Score:5]
# , [Subject:DL ; Score:91]
# ]]
# ]]
# ]]
# , [Year:2024 ; Branches:[[Branch:CSE ; Students:[[Roll No.:1 ; Name:Rajesh Lodwal ; Marks:[[Subject:Maths ; Score:69]
# , [Subject:English ; Score:52]
# , [Subject:ML ; Score:73]
# , [Subject:DL ; Score:99]
# ]]
# , [Roll No.:2 ; Name:Alice Patel ; Marks:[[Subject:Maths ; Score:68]
# , [Subject:English ; Score:57]
# , [Subject:ML ; Score:87]
# , [Subject:DL ; Score:61]
# ]]
# , [Roll No.:3 ; Name:Alice Lodwal ; Marks:[[Subject:Maths ; Score:46]
# , [Subject:English ; Score:57]
# , [Subject:ML ; Score:51]
# , [Subject:DL ; Score:46]
# ]]
# , [Roll No.:4 ; Name:Alia Salvi ; Marks:[[Subject:Maths ; Score:99]
# , [Subject:English ; Score:99]
# , [Subject:ML ; Score:16]
# , [Subject:DL ; Score:91]
# ]]
# ]]
# , [Branch:ME ; Students:[[Roll No.:1 ; Name:Rajesh Salvi ; Marks:[[Subject:Maths ; Score:41]
# , [Subject:English ; Score:92]
# , [Subject:ML ; Score:51]
# , [Subject:DL ; Score:10]
# ]]
# ]]
# , [Branch:CG ; Students:[[Roll No.:1 ; Name:Eve Bhardwaj ; Marks:[[Subject:Maths ; Score:47]
# , [Subject:English ; Score:3]
# , [Subject:ML ; Score:28]
# , [Subject:DL ; Score:74]
# ]]
# , [Roll No.:2 ; Name:Katty Lodwal ; Marks:[[Subject:Maths ; Score:86]
# , [Subject:English ; Score:15]
# , [Subject:ML ; Score:18]
# , [Subject:DL ; Score:73]
# ]]
# , [Roll No.:3 ; Name:Katty Salvi ; Marks:[[Subject:Maths ; Score:80]
# , [Subject:English ; Score:21]
# , [Subject:ML ; Score:54]
# , [Subject:DL ; Score:39]
# ]]
# ]]
# ]]
# , [Year:2025 ; Branches:[[Branch:CSE ; Students:[[Roll No.:1 ; Name:John Patel ; Marks:[[Subject:Maths ; Score:67]
# , [Subject:English ; Score:8]
# , [Subject:ML ; Score:75]
# , [Subject:DL ; Score:5]
# ]]
# , [Roll No.:2 ; Name:Eve Shah ; Marks:[[Subject:Maths ; Score:52]
# , [Subject:English ; Score:91]
# , [Subject:ML ; Score:54]
# , [Subject:DL ; Score:74]
# ]]
# , [Roll No.:3 ; Name:John Patel ; Marks:[[Subject:Maths ; Score:33]
# , [Subject:English ; Score:53]
# , [Subject:ML ; Score:45]
# , [Subject:DL ; Score:25]
# ]]
# ]]
# , [Branch:ME ; Students:[[Roll No.:1 ; Name:Eve Lodwal ; Marks:[[Subject:Maths ; Score:15]
# , [Subject:English ; Score:16]
# , [Subject:ML ; Score:80]
# , [Subject:DL ; Score:5]
# ]]
# , [Roll No.:2 ; Name:Alia Gupta ; Marks:[[Subject:Maths ; Score:17]
# , [Subject:English ; Score:79]
# , [Subject:ML ; Score:94]
# , [Subject:DL ; Score:3]
# ]]
# ]]
# , [Branch:CG ; Students:[[Roll No.:1 ; Name:Katty Gupta ; Marks:[[Subject:Maths ; Score:87]
# , [Subject:English ; Score:11]
# , [Subject:ML ; Score:93]
# , [Subject:DL ; Score:39]
# ]]
# , [Roll No.:2 ; Name:Alice Bhardwaj ; Marks:[[Subject:Maths ; Score:80]
# , [Subject:English ; Score:70]
# , [Subject:ML ; Score:43]
# , [Subject:DL ; Score:30]
# ]]
# , [Roll No.:3 ; Name:Alia Salvi ; Marks:[[Subject:Maths ; Score:67]
# , [Subject:English ; Score:8]
# , [Subject:ML ; Score:13]
# , [Subject:DL ; Score:39]
# ]]
# ]]
# ]]
# ]

# %% [markdown]
# ### ***Question 9:*** Using matplotlib plot the following functions on the domain: x = 0.5 to 100.0 in steps of 0.5.
# ***Answer:*** see below code

# %%
def f(x):
    return x**2
xvalues = numpy.arange(0.5,100.5,0.5, dtype=float)
fig = plt.figure()
plt.subplot(4,2,1)
plt.xlabel("x")
plt.ylabel("x")
plt.plot(xvalues, xvalues)

plt.subplot(4,2,2)
plt.xlabel("x")
plt.ylabel(r"$x^2$")
plt.plot(xvalues, xvalues**2)

plt.subplot(4,2,3)
plt.xlabel("x")
plt.ylabel(r"$\frac{x^3}{100}$")
plt.plot(xvalues, (xvalues**3)/100)

plt.subplot(4,2,4)
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.plot(xvalues, numpy.sin(xvalues))

plt.subplot(4,2,5)
plt.xlabel("x")
plt.ylabel(r"$\frac{sin(x)}{x}$")
plt.plot(xvalues, numpy.sin(xvalues)/xvalues)

plt.subplot(4,2,6)
plt.xlabel("x")
plt.ylabel(r"$log(x)$")
plt.plot(xvalues, numpy.log(xvalues))

plt.subplot(4,2,7)
plt.xlabel("x")
plt.ylabel(r"$e^x$")
plt.plot(xvalues, numpy.power(numpy.full(len(xvalues), numpy.e), xvalues))

fig.set_figwidth(10)
fig.set_figheight(8)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### ***Question 10:*** Using numpy generate a matrix of size 20X5 containing random numbers drawn uniformly from the range of 1 to 2. Using Pandas create a dataframe out of this matrix. Name the columns of the dataframe as “a”, “b”, “c”, “d”, “e”. Find the column with the highest standard deviation. Find the row with the lowest mean.
# ***Answer:*** see below code

# %%
uniformRandomValuea = numpy.random.default_rng().uniform(1.0,2.0,(20,5))
# Out:
# array([[1.12953217, 1.49147784, 1.53195549, 1.69652922, 1.95193477],
#        [1.92821986, 1.97775613, 1.97039873, 1.13519004, 1.73924432],
#        [1.45819139, 1.60465607, 1.07461529, 1.86291377, 1.29461694],
#        [1.04484583, 1.73161023, 1.72496973, 1.07256188, 1.29197295],
#        [1.93620442, 1.54093869, 1.36499808, 1.39523926, 1.40886648],
#        [1.46878431, 1.30070117, 1.43996775, 1.37538444, 1.248954  ],
#        [1.1336387 , 1.51123365, 1.36722102, 1.62122574, 1.86296609],
#        [1.71812831, 1.19712903, 1.64750468, 1.64024366, 1.21900406],
#        [1.35092749, 1.12034131, 1.19927453, 1.70576569, 1.76831779],
#        [1.0666636 , 1.52654253, 1.54110507, 1.78415091, 1.020002  ],
#        [1.05056697, 1.86368404, 1.20429002, 1.22676833, 1.6065571 ],
#        [1.38424131, 1.94993972, 1.88821522, 1.1961091 , 1.57859951],
#        [1.69716142, 1.23310425, 1.33730059, 1.82077244, 1.85376472],
#        [1.5832239 , 1.10469244, 1.27598672, 1.13948485, 1.5150302 ],
#        [1.15269211, 1.51318522, 1.44428443, 1.38985701, 1.39909316],
#        [1.61764571, 1.64704921, 1.96567344, 1.95889352, 1.66114329],
#        [1.88281965, 1.19204834, 1.35092787, 1.417494  , 1.67869744],
#        [1.79337762, 1.85444497, 1.08461358, 1.77571304, 1.88477979],
#        [1.67685559, 1.67115606, 1.97281075, 1.60881871, 1.93568137],
#        [1.95205759, 1.6464946 , 1.65754547, 1.53144057, 1.31609745]])
